# %%
# %pip install optuna
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import pandas as pd
import os
import json
import time
from itertools import product
from tqdm import tqdm 
import optuna
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: optuna in c:\users\andrea\anaconda3\lib\site-packages (4.5.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (1.16.5)
# Requirement already satisfied: colorlog in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\andrea\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\andrea\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\andrea\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\andrea\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\andrea\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\andrea\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)

# %%
class LSTMTemporalFeatureExtractor(nn.Module):
    """
    LSTM component for hybrid models that produces 32-dimensional temporal features
    Compatible with: CapsNet-LSTM-LightGBM, CNN-LSTM-LightGBM, CapsNet-LSTM
    """
    def __init__(self, input_size, hidden_size=64, num_layers=1, dropout=0.2, 
                 activation='relu', lstm_dropout=0.0):
        super(LSTMTemporalFeatureExtractor, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        # LSTM layers
        self.lstm = nn.LSTM(
            input_size=input_size, 
            hidden_size=hidden_size, 
            num_layers=num_layers,
            dropout=lstm_dropout if num_layers > 1 else 0,
            batch_first=True
        )
        
        # Activation function
        if activation == 'relu':
            self.activation = nn.ReLU()
        elif activation == 'tanh':
            self.activation = nn.Tanh()
        elif activation == 'gelu':
            self.activation = nn.GELU()
        else:
            self.activation = nn.ReLU()
        
        self.dropout = nn.Dropout(dropout)
        
        # Feature extraction layer (32 dimensions for hybrid integration)
        self.temporal_feature_layer = nn.Linear(hidden_size, 32)
        
        # Optional prediction layer (for CapsNet-LSTM model without LightGBM)
        self.prediction_layer = nn.Linear(32, 1)
        
    def forward(self, x, return_features_only=False):
        """
        Forward pass with option to return only temporal features or full prediction
        
        Args:
            x: Input sequences (batch_size, seq_len, features)
            return_features_only: If True, returns only 32-dim temporal features
                                If False, returns both features and prediction
        
        Returns:
            temporal_features: 32-dimensional temporal features for hybrid models
            prediction: PM2.5 prediction (only if return_features_only=False)
        """
        # LSTM forward pass
        lstm_out, (hn, cn) = self.lstm(x)
        last_output = lstm_out[:, -1, :]  # Use last timestep output
        
        # Extract 32-dimensional temporal features
        temporal_features = self.activation(self.temporal_feature_layer(last_output))
        temporal_features = self.dropout(temporal_features)
        
        if return_features_only:
            return temporal_features
        else:
            # For CapsNet-LSTM model (without LightGBM)
            prediction = self.prediction_layer(temporal_features)
            return temporal_features, prediction

# %%
# FOR TRAINING
class LSTMTemporalFeatureGenerator:
    """
    LSTM component for temporal feature extraction in hybrid models
    Designed to work within full pipeline cross-validation
    """
    def __init__(self, best_params=None):
        # Default hyperparameters (should be determined through separate tuning)
        self.default_params = {
            'hidden_size': 64,
            'num_layers': 1,
            'dropout': 0.2,
            'activation': 'relu',
            'learning_rate': 0.001,
            'batch_size': 32,
            'epochs': 50,
            'timesteps': 60,  # Default temporal window size
            'weight_decay': 0.0,
            'grad_clip': 1.0,
            'lstm_dropout': 0.0
        }
        
        self.params = best_params if best_params else self.default_params
        self.scaler = None
        self.model = None
        
    def prepare_temporal_sequences(self, temporal_data, targets, timesteps=10):
        """
        Prepare temporal sequences for a given fold
        Called during each CV fold by the full pipeline
        """
        # Scale temporal features
        if self.scaler is None:
            self.scaler = MinMaxScaler()
            temporal_data_scaled = self.scaler.fit_transform(temporal_data)
        else:
            temporal_data_scaled = self.scaler.transform(temporal_data)
        
        # Create sequences
        X, y = [], []
        for i in range(len(temporal_data_scaled) - timesteps):
            X.append(temporal_data_scaled[i:i+timesteps])
            y.append(targets[i+timesteps])
        
        return np.array(X), np.array(y)
    
    def train_and_extract_features(self, train_temporal_data, train_targets, val_temporal_data, val_targets, timesteps=None):
        """
        Train LSTM and extract temporal features for current CV fold
        This is called by the full pipeline during each fold
        
        IMPORTANT: val_temporal_data is validation data from the 80% learning set,
                   NOT the 20% hold-out test set (to prevent data leakage)
        
        Returns:
            train_features: 32D temporal features for training data
            val_features: 32D temporal features for validation data (within learning set)
        """
        # Use timesteps from params or default
        if timesteps is None:
            timesteps = self.params.get('timesteps', 60)
            
        # Prepare sequences for training
        X_train, y_train = self.prepare_temporal_sequences(train_temporal_data, train_targets, timesteps)
        
        # Convert to tensors
        X_train_tensor = torch.FloatTensor(X_train)
        y_train_tensor = torch.FloatTensor(y_train).unsqueeze(1)
        
        # Create data loader
        train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
        train_loader = DataLoader(train_dataset, batch_size=self.params['batch_size'], shuffle=True)
        
        # Initialize LSTM model
        self.model = LSTMTemporalFeatureExtractor(
            input_size=train_temporal_data.shape[1],
            hidden_size=self.params['hidden_size'],
            num_layers=self.params['num_layers'],
            dropout=self.params['dropout'],
            activation=self.params['activation'],
            lstm_dropout=self.params.get('lstm_dropout', 0.0)
        )
        
        criterion = nn.MSELoss()
        optimizer = optim.Adam(
            self.model.parameters(), 
            lr=self.params['learning_rate'],
            weight_decay=self.params.get('weight_decay', 0.0)
        )
        
        # Training loop
        self.model.train()
        for epoch in range(self.params['epochs']):
            total_loss = 0
            for batch_X, batch_y in train_loader:
                optimizer.zero_grad()
                _, predictions = self.model(batch_X, return_features_only=False)
                loss = criterion(predictions, batch_y)
                loss.backward()
                
                # Gradient clipping
                torch.nn.utils.clip_grad_norm_(
                    self.model.parameters(), 
                    max_norm=self.params.get('grad_clip', 1.0)
                )
                
                optimizer.step()
                total_loss += loss.item()
        
        # Extract features from training data
        self.model.eval()
        with torch.no_grad():
            train_features = self.model(X_train_tensor, return_features_only=True).numpy()
        
        # Prepare test sequences and extract features
        X_val, _ = self.prepare_temporal_sequences(val_temporal_data, val_targets, timesteps)
        X_val_tensor = torch.FloatTensor(X_val)
        
        with torch.no_grad():
            val_features = self.model(X_val_tensor, return_features_only=True).numpy()
        
        # Debug: Verify numpy arrays are generated correctly
        print(f"  LSTM Debug - Train features shape: {train_features.shape}, type: {type(train_features)}")
        print(f"  LSTM Debug - Val features shape: {val_features.shape}, type: {type(val_features)}")
        print(f"  LSTM Debug - Feature sample: {train_features[0][:5]}...")  # First 5 values
        
        return train_features, val_features, y_train, X_val.shape[0]

# %%
class TemporalDataLoader:
    """
    Data loader for temporal features across all days
    Supports full pipeline cross-validation
    """
    def __init__(self, days=['10_19', '11_10', '7_24']):
        self.days = days
        self.temporal_features = ['pm10', 'temperature', 'humidity']
    
    def load_temporal_data(self, day):
        """
        Load temporal data for a specific day
        Returns raw temporal data and targets for CV splitting
        """
        matched_file = f'../../dataset/c_matched_spatio_temporal_data/matched_{day}.csv'
        if not os.path.exists(matched_file):
            raise FileNotFoundError(f"Matched data not found: {matched_file}")
        
        df = pd.read_csv(matched_file)
        
        # Sort by timestamp for proper time series handling
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        df = df.sort_values('timestamp').reset_index(drop=True)
        
        # Get available temporal features
        available_features = [col for col in self.temporal_features if col in df.columns]
        
        if not available_features:
            raise ValueError(f"No temporal features found in {day}")
        
        # Remove rows with missing values
        required_cols = available_features + ['pm2.5']
        
        df_clean = df.dropna(subset=required_cols)
        
        temporal_data = df_clean[available_features].values
        targets = df_clean['pm2.5'].values
        
        return temporal_data, targets, available_features

# %%
def hyperparameter_tuning_lstm(day, n_trials=30):
    """
    Hyperparameter tuning for LSTM component using Optuna.
    """
    print(f"LSTM Hyperparameter Tuning for {day}")
    print("=" * 50)

    # Load data
    data_loader = TemporalDataLoader()
    temporal_data, targets, feature_names = data_loader.load_temporal_data(day)

    n_total = len(temporal_data)
    n_learning = int(n_total * 0.8)
    learning_temporal = temporal_data[:n_learning]
    learning_targets = targets[:n_learning]

    n_tune_train = int(n_learning * 0.8)
    tune_train_temporal = learning_temporal[:n_tune_train]
    tune_train_targets = learning_targets[:n_tune_train]
    tune_val_temporal = learning_temporal[n_tune_train:]
    tune_val_targets = learning_targets[n_tune_train:]
 
    def objective(trial):
        params = {
            'hidden_size': trial.suggest_categorical('hidden_size', [32, 64, 128, 256]),
            'num_layers': trial.suggest_int('num_layers', 1, 3),
            'dropout': trial.suggest_categorical('dropout', [0.1, 0.2, 0.3, 0.4]),
            'activation': trial.suggest_categorical('activation', ['relu', 'tanh', 'gelu']),
            'learning_rate': trial.suggest_float('learning_rate', 0.0001, 0.01, log=True),
            'batch_size': trial.suggest_categorical('batch_size', [16, 32, 64]),
            'epochs': trial.suggest_categorical('epochs', [10, 30, 50]),
            'timesteps': trial.suggest_categorical('timesteps', [10, 30, 40, 60]),
            'weight_decay': trial.suggest_categorical('weight_decay', [0.0, 1e-5, 1e-4]),
            'grad_clip': trial.suggest_categorical('grad_clip', [0.5, 1.0, 2.0]),
            'lstm_dropout': trial.suggest_categorical('lstm_dropout', [0.0, 0.1, 0.2])
        }
        lstm_gen = LSTMTemporalFeatureGenerator(params)
        try:
            train_features, val_features, train_y, val_len = lstm_gen.train_and_extract_features(
                tune_train_temporal, tune_train_targets, tune_val_temporal, tune_val_targets,
                timesteps=params['timesteps']
            )
            val_y = tune_val_targets[params['timesteps']:]
            if len(val_y) == len(val_features):
                from sklearn.linear_model import LinearRegression
                lr = LinearRegression()
                lr.fit(train_features, train_y)
                val_pred = lr.predict(val_features)
                mse = mean_squared_error(val_y, val_pred)
                return mse
            else:
                return float('inf')
        except Exception as e:
            print(f"Optuna trial error: {e}")
            return float('inf')

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

    best_params = study.best_params
    best_score = study.best_value

    os.makedirs('models/lstm_temporal', exist_ok=True)
    with open(f'models/lstm_temporal/{day}_best_params.json', 'w') as f:
        json.dump(best_params, f, indent=2)

    print(f"Best parameters for {day}: {best_params}")
    print(f"Best validation RMSE: {np.sqrt(best_score):.4f}")

    return best_params

# %%
def main():
    """
    Main execution for LSTM temporal feature extraction
    Focused on component preparation for full pipeline CV
    """
    print("="*80)
    print("LSTM TEMPORAL FEATURE EXTRACTION - PIPELINE READY")
    print("="*80)
    print("Purpose: Prepare LSTM component for full pipeline cross-validation")
    print("- Hyperparameter tuning for each day")
    print("- Component ready for CV integration")
    print("- No standalone evaluation (done in full pipeline)")
    print("="*80)

    days = ['10_19', '11_10', '7_24']

    # Step 1: Hyperparameter tuning for each day
    print("\nStep 1: LSTM Hyperparameter Tuning")
    print("-" * 50)
    
    for day in days:
        try:
            print(f"\nTuning LSTM parameters for {day}...")
            best_params = hyperparameter_tuning_lstm(day, n_trials=30)
            print(f" {day} tuning complete")
            
        except Exception as e:
            print(f" Error tuning {day}: {str(e)}")
    
    print(f"\n{'='*80}")
    print("LSTM COMPONENT PREPARATION COMPLETE")
    print("="*80)
    print("Best parameters saved for each day")
    print("LSTMTemporalFeatureGenerator class ready")
    print("TemporalDataLoader class ready")
    print("\nNext Steps:")
    print("1. Integration team: Use LSTMTemporalFeatureGenerator in full pipeline")
    print("2. Full pipeline CV: Wrap entire models in 5-fold cross-validation")
    print("3. Models to evaluate: CapsNet-LSTM-LightGBM, CNN-LSTM-LightGBM, CapsNet-LSTM")
    print("4. Statistical analysis: Compare 5-fold results across models")
    print("="*80)
    
    # Example usage for integration team
    print("\n" + "="*80)
    print("CORRECT 5-FOLD CV INTEGRATION:")
    print("="*80)
    print("""
# PHASE 1: Hyperparameter Tuning (run once per day)
from lstm_temporal_feature_generator import hyperparameter_tuning_lstm
best_params = hyperparameter_tuning_lstm('7_24', max_combinations=10)

# PHASE 2: 5-Fold Cross-Validation (main pipeline)
from lstm_temporal_feature_generator import LSTMTemporalFeatureGenerator, TemporalDataLoader
from sklearn.model_selection import TimeSeriesSplit

# Initialize components
data_loader = TemporalDataLoader()
lstm_generator = LSTMTemporalFeatureGenerator(best_params)

# Load data and split into learning (80%) and hold-out (20%)
temporal_data, targets, _ = data_loader.load_temporal_data('7_24')
n_total = len(temporal_data)
n_learning = int(n_total * 0.8)

learning_temporal = temporal_data[:n_learning]  # 80% learning set
learning_targets = targets[:n_learning]
holdout_temporal = temporal_data[n_learning:]   # 20% hold-out (untouched)
holdout_targets = targets[n_learning:]

# 5-Fold TimeSeriesSplit on 80% learning set
tscv = TimeSeriesSplit(n_splits=5)
fold_scores = []

for fold, (train_idx, val_idx) in enumerate(tscv.split(learning_temporal)):
    print(f"Fold {fold + 1}/5")
    
    # Split data for this fold (expanding window)
    train_temporal = learning_temporal[train_idx]  # Growing train set
    val_temporal = learning_temporal[val_idx]      # Fixed-size val set
    train_targets = learning_targets[train_idx]
    val_targets = learning_targets[val_idx]
    
    # Extract temporal features for this fold
    train_temp_features, val_temp_features, _, _ = lstm_generator.train_and_extract_features(
        train_temporal, train_targets, val_temporal, val_targets
    )
    
    # Extract spatial features (CapsNet/CNN)
    train_spatial_features, val_spatial_features = capsnet_generator.train_and_extract_features(
        train_images, train_targets, val_images, val_targets
    )
    
    # Combine features
    train_combined = np.concatenate([train_temp_features, train_spatial_features], axis=1)
    val_combined = np.concatenate([val_temp_features, val_spatial_features], axis=1)
    
    # Train LightGBM meta-learner
    lightgbm_model = LGBMRegressor(best_lightgbm_params)
    lightgbm_model.fit(train_combined, train_targets)
    
    # Validate on this fold
    val_predictions = lightgbm_model.predict(val_combined)
    fold_rmse = np.sqrt(mean_squared_error(val_targets, val_predictions))
    fold_scores.append(fold_rmse)
    
    print(f"  Fold {fold + 1} RMSE: {fold_rmse:.4f}")

# Calculate cross-validation performance
cv_mean = np.mean(fold_scores)
cv_std = np.std(fold_scores)
print(f"5-Fold CV Results: {cv_mean:.4f} ± {cv_std:.4f}")
""")
    print("="*80)

# %%
if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# LSTM TEMPORAL FEATURE EXTRACTION - PIPELINE READY
# ================================================================================
# Purpose: Prepare LSTM component for full pipeline cross-validation
# - Hyperparameter tuning for each day
# - Component ready for CV integration
# - No standalone evaluation (done in full pipeline)
# ================================================================================
#
# Step 1: LSTM Hyperparameter Tuning
# --------------------------------------------------
#
# Tuning LSTM parameters for 10_19...
# LSTM Hyperparameter Tuning for 10_19
# ==================================================
# [I 2025-09-16 10:46:44,578] A new study created in memory with name: no-name-c961bcdc-607d-49ed-bd3b-a11967864fae
#   0%|          | 0/30 [00:00<?, ?it/s]
#   LSTM Debug - Train features shape: (79258, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19807, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.05900816  0.02189298 -0.00196111  0.00867482 -0.01650273]...
# [I 2025-09-16 11:04:05,365] Trial 0 finished with value: 48.804454784452595 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.008612153244425614, 'batch_size': 64, 'epochs': 50, 'timesteps': 10, 'weight_decay': 1e-05, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 0 with value: 48.804454784452595.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 29936782584 bytes.
# [I 2025-09-16 11:51:13,783] Trial 1 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.4, 'activation': 'gelu', 'learning_rate': 0.00010371077565202166, 'batch_size': 32, 'epochs': 10, 'timesteps': 40, 'weight_decay': 0.0, 'grad_clip': 2.0, 'lstm_dropout': 0.1}. Best is trial 0 with value: 48.804454784452595.
#   LSTM Debug - Train features shape: (79258, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19807, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.15612912 -0.16990091  0.44967926  0.8174959   0.06610291]...
# [I 2025-09-16 12:16:10,511] Trial 2 finished with value: 68.32935297495835 and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.3, 'activation': 'gelu', 'learning_rate': 0.009196011664518028, 'batch_size': 64, 'epochs': 30, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 0.5, 'lstm_dropout': 0.1}. Best is trial 0 with value: 48.804454784452595.
#   LSTM Debug - Train features shape: (79238, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19787, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.        0.        2.9664586 0.        0.       ]...
# [I 2025-09-16 12:26:46,794] Trial 3 finished with value: 70.52162493050993 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'relu', 'learning_rate': 0.006069301156977866, 'batch_size': 16, 'epochs': 10, 'timesteps': 30, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.0}. Best is trial 0 with value: 48.804454784452595.
#   LSTM Debug - Train features shape: (79258, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19807, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 7.215016   -0.1699697   5.734004   -0.16963616  6.031311  ]...
# [I 2025-09-16 12:29:22,074] Trial 4 finished with value: 54.30865796091338 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'activation': 'gelu', 'learning_rate': 0.00036047712206651244, 'batch_size': 32, 'epochs': 10, 'timesteps': 10, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.0}. Best is trial 0 with value: 48.804454784452595.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 20829809912 bytes.
# [I 2025-09-16 13:58:54,580] Trial 5 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.4, 'activation': 'gelu', 'learning_rate': 0.0015012176592241442, 'batch_size': 16, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.1}. Best is trial 0 with value: 48.804454784452595.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.61871755  0.65538377 -0.632902    0.4942895  -0.68623435]...
# [I 2025-09-16 14:12:41,942] Trial 6 finished with value: 47.248076057084276 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0005745396068804826, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.0}. Best is trial 6 with value: 47.248076057084276.
#   LSTM Debug - Train features shape: (79238, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19787, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.9999852  0.9999992 -0.9999706 -0.9999844  0.9999972]...
# [I 2025-09-16 14:18:09,437] Trial 7 finished with value: 3000.2608571284177 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3, 'activation': 'tanh', 'learning_rate': 0.0006969044099280566, 'batch_size': 64, 'epochs': 10, 'timesteps': 30, 'weight_decay': 0.0, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 6 with value: 47.248076057084276.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 20829809912 bytes.
# [I 2025-09-16 15:03:30,222] Trial 8 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 1, 'dropout': 0.1, 'activation': 'gelu', 'learning_rate': 0.00029456612700651285, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 6 with value: 47.248076057084276.
#   LSTM Debug - Train features shape: (79258, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19807, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.       12.451427  0.        0.        0.      ]...
# [I 2025-09-16 15:17:55,931] Trial 9 finished with value: 72.48486767620034 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.4, 'activation': 'gelu', 'learning_rate': 0.003357087032858887, 'batch_size': 64, 'epochs': 10, 'timesteps': 10, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 6 with value: 47.248076057084276.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.26393077  0.5148424  -0.53939205 -0.46451887  0.3578636 ]...
# [I 2025-09-16 15:28:08,492] Trial 10 finished with value: 46.281928675886775 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0015505456204950062, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 10 with value: 46.281928675886775.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.52732414 -0.36252156 -0.52439433  0.41316113  0.48709524]...
# [I 2025-09-16 15:38:13,416] Trial 11 finished with value: 46.81301944225285 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0017254966829660678, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 10 with value: 46.281928675886775.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.5432947  -0.60167235  0.599333   -0.5203072  -0.5164168 ]...
# [I 2025-09-16 15:48:24,727] Trial 12 finished with value: 46.56057357382085 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0018176420538984816, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 10 with value: 46.281928675886775.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.5242558  -0.48155293  0.34947303  0.39843014  0.3329911 ]...
# [I 2025-09-16 15:58:30,510] Trial 13 finished with value: 47.703416411414764 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.2, 'activation': 'tanh', 'learning_rate': 0.0029769849726272225, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 10 with value: 46.281928675886775.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [3.730546  3.7205617 3.017318  3.1132653 3.3477504]...
# [I 2025-09-16 16:20:35,601] Trial 14 finished with value: 46.022485177780354 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.001274651111817904, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [4.3256373 4.6310787 3.9373214 4.379389  3.9777787]...
# [I 2025-09-16 16:42:43,145] Trial 15 finished with value: 48.56433421037795 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.0008806086143948104, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.36486983 0.08979827 0.         0.         0.        ]...
# [I 2025-09-16 17:17:58,240] Trial 16 finished with value: 63.65769631389998 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.003476767081416182, 'batch_size': 16, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [2.5561793 2.3151364 3.215194  2.4978411 2.6937633]...
# [I 2025-09-16 17:54:45,892] Trial 17 finished with value: 47.87561490656218 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.0012854512989331694, 'batch_size': 32, 'epochs': 50, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79238, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19787, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [8.932587  0.        0.        7.9882565 0.       ]...
# [I 2025-09-16 18:14:16,764] Trial 18 finished with value: 46.892442460605835 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.0003702266176501462, 'batch_size': 32, 'epochs': 30, 'timesteps': 30, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 43514991864 bytes.
# [I 2025-09-16 23:37:18,619] Trial 19 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.0001816664935879644, 'batch_size': 32, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.7572486  0.850687   0.9084731  0.93872243 0.70198995]...
# [I 2025-09-17 00:21:46,440] Trial 20 finished with value: 53.48080419848052 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.002417148329319146, 'batch_size': 16, 'epochs': 50, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.39223748  0.18222237  0.34433097 -0.3756369   0.39722615]...
# [I 2025-09-17 00:31:55,042] Trial 21 finished with value: 46.421169444654666 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.001992981101565694, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.58588743 -0.6401744   0.5632578  -0.5915909   0.5980202 ]...
# [I 2025-09-17 00:42:06,688] Trial 22 finished with value: 46.09823973714111 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.001010003773256255, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.36815152 0.51203114 0.53201795 0.5361126  0.38266435]...
# [I 2025-09-17 00:52:19,756] Trial 23 finished with value: 47.065489963184326 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0010307401045593007, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.592821   -0.6963489   0.6324142  -0.78275084  0.75732845]...
# [I 2025-09-17 01:02:29,390] Trial 24 finished with value: 46.47619116786836 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0005544429373795282, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.57058007 0.35047248 0.68902653 0.6050709  0.6305356 ]...
# [I 2025-09-17 01:12:42,965] Trial 25 finished with value: 46.58369448819724 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.005137053622825267, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79228, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19777, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.4646388   0.47424453  0.43893796 -0.55986494  0.33964235]...
# [I 2025-09-17 01:28:56,418] Trial 26 finished with value: 47.535332576258654 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.001034530725359739, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 23145115896 bytes.
# [I 2025-09-17 02:14:31,569] Trial 27 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 1, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.0008346628942084315, 'batch_size': 32, 'epochs': 30, 'timesteps': 30, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 20829809912 bytes.
# [I 2025-09-17 04:06:10,996] Trial 28 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.3, 'activation': 'tanh', 'learning_rate': 0.0012858213431509258, 'batch_size': 32, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.2}. Best is trial 14 with value: 46.022485177780354.
#   LSTM Debug - Train features shape: (79258, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19807, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.5398631  -0.5108524   0.52936095  0.47231525 -0.53944457]...
# [I 2025-09-17 04:45:03,868] Trial 29 finished with value: 50.08006986317681 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.2, 'activation': 'tanh', 'learning_rate': 0.0004597417284730807, 'batch_size': 16, 'epochs': 50, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.1}. Best is trial 14 with value: 46.022485177780354.
# Best parameters for 10_19: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.001274651111817904, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}
# Best validation RMSE: 6.7840
#  10_19 tuning complete
#
# Tuning LSTM parameters for 11_10...
# LSTM Hyperparameter Tuning for 11_10
# ==================================================
# [I 2025-09-17 04:45:05,031] A new study created in memory with name: no-name-cfd15765-bff2-4637-aedb-ec2cae778fb6
#   0%|          | 0/30 [00:00<?, ?it/s]
#   LSTM Debug - Train features shape: (76243, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19054, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [3.8667135 4.2521696 4.7796783 4.4407206 3.576949 ]...
# [I 2025-09-17 05:07:40,058] Trial 0 finished with value: 56.57007318396647 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.0006923750438841051, 'batch_size': 16, 'epochs': 30, 'timesteps': 10, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.1}. Best is trial 0 with value: 56.57007318396647.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 10030672696 bytes.
# [I 2025-09-17 05:20:31,411] Trial 1 finished with value: inf and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.1, 'activation': 'gelu', 'learning_rate': 0.007111963495160177, 'batch_size': 64, 'epochs': 10, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 0 with value: 56.57007318396647.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 28797558520 bytes.
# [I 2025-09-17 09:08:12,568] Trial 2 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.3, 'activation': 'tanh', 'learning_rate': 0.00014922798388885972, 'batch_size': 32, 'epochs': 50, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 0 with value: 56.57007318396647.
#   LSTM Debug - Train features shape: (76243, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19054, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0. 0. 0. 0. 0.]...
# [I 2025-09-17 09:37:02,339] Trial 3 finished with value: 119.60686178877981 and parameters: {'hidden_size': 256, 'num_layers': 1, 'dropout': 0.3, 'activation': 'gelu', 'learning_rate': 0.008673869997317606, 'batch_size': 64, 'epochs': 50, 'timesteps': 10, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.2}. Best is trial 0 with value: 56.57007318396647.
#   LSTM Debug - Train features shape: (76243, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19054, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.67957425  0.56042737  0.66556174 -0.63308555  0.41613984]...
# [I 2025-09-17 09:54:30,747] Trial 4 finished with value: 69.80193447200054 and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.002253609657198447, 'batch_size': 32, 'epochs': 10, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.1}. Best is trial 0 with value: 56.57007318396647.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 28797558520 bytes.
# [I 2025-09-17 11:08:45,225] Trial 5 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0002799015601286624, 'batch_size': 32, 'epochs': 10, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 0 with value: 56.57007318396647.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [5.797082  4.2032804 5.8597903 5.534053  6.165166 ]...
# [I 2025-09-17 11:20:50,953] Trial 6 finished with value: 50.14576746703998 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0008487861129830975, 'batch_size': 32, 'epochs': 10, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 6 with value: 50.14576746703998.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 22264447736 bytes.
# [I 2025-09-17 12:55:48,198] Trial 7 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 2, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0009765410032883729, 'batch_size': 64, 'epochs': 30, 'timesteps': 30, 'weight_decay': 0.0, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 6 with value: 50.14576746703998.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [3.354398  4.085297  3.6329007 3.8747666 4.056108 ]...
# [I 2025-09-17 13:31:29,478] Trial 8 finished with value: 46.75927758276413 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.0002912747545015228, 'batch_size': 32, 'epochs': 50, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.2}. Best is trial 8 with value: 46.75927758276413.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [3.5006533 3.351205  2.5704641 3.2650535 3.1640413]...
# [I 2025-09-17 13:40:12,865] Trial 9 finished with value: 56.876810225320476 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.001231783232118059, 'batch_size': 16, 'epochs': 10, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.1}. Best is trial 8 with value: 46.75927758276413.
#   LSTM Debug - Train features shape: (76223, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19034, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.79396904  0.7587343  -0.7405439  -0.74235076  0.7323971 ]...
# [I 2025-09-17 13:55:14,301] Trial 10 finished with value: 76.41361845599488 and parameters: {'hidden_size': 32, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.00010661751601884708, 'batch_size': 32, 'epochs': 50, 'timesteps': 30, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 8 with value: 46.75927758276413.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 13798842872 bytes.
# [I 2025-09-17 16:04:49,799] Trial 11 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0003830715972776739, 'batch_size': 32, 'epochs': 50, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 8 with value: 46.75927758276413.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [3.055958  3.105233  3.4538674 2.7460544 3.4082484]...
# [I 2025-09-17 17:03:22,461] Trial 12 finished with value: 42.73957487720116 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0003811843255131223, 'batch_size': 32, 'epochs': 50, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
#   LSTM Debug - Train features shape: (76193, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19004, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [3.0982497 3.6391747 3.2232885 3.8053157 3.8634052]...
# [I 2025-09-17 17:45:51,123] Trial 13 finished with value: 44.1965046577558 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.0002907061455220942, 'batch_size': 32, 'epochs': 50, 'timesteps': 60, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 20036955640 bytes.
# [I 2025-09-17 20:41:40,452] Trial 14 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.00018823008674648703, 'batch_size': 32, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
#   LSTM Debug - Train features shape: (76193, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19004, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 2.7599368   2.3598688  -0.16997097  2.4238684  -0.16997097]...
# [I 2025-09-17 22:08:25,383] Trial 15 finished with value: 50.8532368598991 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.3, 'activation': 'gelu', 'learning_rate': 0.0004801877518122206, 'batch_size': 16, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 10030672376 bytes.
# [I 2025-09-17 23:23:59,110] Trial 16 finished with value: inf and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.001990286869732342, 'batch_size': 32, 'epochs': 50, 'timesteps': 60, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 10030672376 bytes.
# [I 2025-09-17 23:40:14,851] Trial 17 finished with value: inf and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'relu', 'learning_rate': 0.0002043556946714662, 'batch_size': 32, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
#   LSTM Debug - Train features shape: (76223, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19034, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.16817681 -0.16490684 -0.16056243 -0.16430672 -0.1690496 ]...
# [I 2025-09-17 23:55:11,565] Trial 18 finished with value: 44.5531729381882 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'activation': 'gelu', 'learning_rate': 0.0005343723133929704, 'batch_size': 64, 'epochs': 50, 'timesteps': 30, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 20036955640 bytes.
# [I 2025-09-18 03:45:24,486] Trial 19 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.3, 'activation': 'tanh', 'learning_rate': 0.0016790766459732589, 'batch_size': 16, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 12 with value: 42.73957487720116.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.19902012 0.29412192 0.22331147 0.17620364 0.19964296]...
# [I 2025-09-18 04:20:13,507] Trial 20 finished with value: 38.49041938225425 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.0033950933874562356, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 20 with value: 38.49041938225425.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0. 0. 0. 0. 0.]...
# [I 2025-09-18 04:55:16,737] Trial 21 finished with value: 119.74754110043588 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.0038586045203401103, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 20 with value: 38.49041938225425.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.10163736 0.18320005 0.03022373 0.16733639 0.13862275]...
# [I 2025-09-18 05:30:10,798] Trial 22 finished with value: 34.86826869856414 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.003980524160966534, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0. 0. 0. 0. 0.]...
# [I 2025-09-18 06:04:52,752] Trial 23 finished with value: 119.74754110043588 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.004287413466552687, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.14241979 0.01438394 0.07307035 0.         0.09237659]...
# [I 2025-09-18 06:39:55,568] Trial 24 finished with value: 43.85441890674214 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.004437554429030945, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.7861859 0.9263793 0.8781713 0.80134   0.8303053]...
# [I 2025-09-18 07:04:03,278] Trial 25 finished with value: 41.70781559321938 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0029286502498174017, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.18948522 0.30316746 0.41118723 0.26918778 0.41518056]...
# [I 2025-09-18 07:28:25,756] Trial 26 finished with value: 38.176264558747114 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'relu', 'learning_rate': 0.0031830859785921604, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.         0.10567302 0.0806414  0.12674806 0.05814311]...
# [I 2025-09-18 07:52:35,913] Trial 27 finished with value: 39.38683848472848 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'relu', 'learning_rate': 0.006874281126371505, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76213, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19024, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.16026402 -0.17323275 -0.21636072 -0.21873051  0.1281294 ]...
# [I 2025-09-18 08:11:25,261] Trial 28 finished with value: 50.36601750978185 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0029353165280810263, 'batch_size': 64, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
#   LSTM Debug - Train features shape: (76243, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (19054, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.16994007 -0.1669349  -0.16996755 -0.16824576 -0.16982397]...
# [I 2025-09-18 08:26:15,054] Trial 29 finished with value: 35.55043759188 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.1, 'activation': 'gelu', 'learning_rate': 0.005657614515538041, 'batch_size': 16, 'epochs': 30, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 22 with value: 34.86826869856414.
# Best parameters for 11_10: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.003980524160966534, 'batch_size': 32, 'epochs': 30, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}
# Best validation RMSE: 5.9049
#  11_10 tuning complete
#
# Tuning LSTM parameters for 7_24...
# LSTM Hyperparameter Tuning for 7_24
# ==================================================
# [I 2025-09-18 08:26:15,737] A new study created in memory with name: no-name-01d34a47-8273-4545-8f35-e70901a4ff25
#   0%|          | 0/30 [00:00<?, ?it/s]
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [1.908302  3.2041874 0.        3.282769  0.       ]...
# [I 2025-09-18 08:55:09,313] Trial 0 finished with value: 27.269743446601478 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'activation': 'relu', 'learning_rate': 0.00023558107421360489, 'batch_size': 32, 'epochs': 50, 'timesteps': 60, 'weight_decay': 1e-05, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 0 with value: 27.269743446601478.
#   LSTM Debug - Train features shape: (41326, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10310, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.29645577  0.2931873   0.16745739 -0.25595516 -0.26003963]...
# [I 2025-09-18 09:11:24,098] Trial 1 finished with value: 27.23398130312492 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0011814731032148225, 'batch_size': 16, 'epochs': 50, 'timesteps': 30, 'weight_decay': 0.0001, 'grad_clip': 0.5, 'lstm_dropout': 0.2}. Best is trial 1 with value: 27.23398130312492.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 15611518200 bytes.
# [I 2025-09-18 11:31:45,030] Trial 2 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.00016830661815747446, 'batch_size': 16, 'epochs': 30, 'timesteps': 40, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.1}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41316, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10300, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-1.  1.  1.  1. -1.]...
# [I 2025-09-18 12:02:25,497] Trial 3 finished with value: 27.744520330698414 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0047925586917508655, 'batch_size': 16, 'epochs': 50, 'timesteps': 40, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.1}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41326, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10310, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [2.135932  0.        1.4712819 1.9349229 0.       ]...
# [I 2025-09-18 12:13:56,093] Trial 4 finished with value: 28.580117841928892 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.0005037346679171327, 'batch_size': 16, 'epochs': 30, 'timesteps': 30, 'weight_decay': 0.0, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41346, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10330, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0. 0. 0. 0. 0.]...
# [I 2025-09-18 12:34:37,833] Trial 5 finished with value: 27.936714478518173 and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout': 0.3, 'activation': 'relu', 'learning_rate': 0.005067320300251218, 'batch_size': 16, 'epochs': 10, 'timesteps': 10, 'weight_decay': 1e-05, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41316, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10300, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.25298682 -0.15551667 -0.16106848 -0.16000293 -0.16195472]...
# [I 2025-09-18 12:53:54,874] Trial 6 finished with value: 31.494836482745065 and parameters: {'hidden_size': 32, 'num_layers': 3, 'dropout': 0.3, 'activation': 'gelu', 'learning_rate': 0.002358523870228385, 'batch_size': 32, 'epochs': 50, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 1 with value: 27.23398130312492.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 12071174392 bytes.
# [I 2025-09-18 14:47:10,508] Trial 7 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 3, 'dropout': 0.2, 'activation': 'gelu', 'learning_rate': 0.00013875255716364797, 'batch_size': 16, 'epochs': 30, 'timesteps': 30, 'weight_decay': 1e-05, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41326, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10310, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-1.  1. -1.  1.  1.]...
# [I 2025-09-18 15:14:04,432] Trial 8 finished with value: 27.830494633008268 and parameters: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.3, 'activation': 'tanh', 'learning_rate': 0.0010298841252704715, 'batch_size': 32, 'epochs': 50, 'timesteps': 30, 'weight_decay': 0.0, 'grad_clip': 0.5, 'lstm_dropout': 0.2}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [0.        0.        1.9685799 0.        2.0679564]...
# [I 2025-09-18 15:19:30,956] Trial 9 finished with value: 32.40831309359223 and parameters: {'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'activation': 'relu', 'learning_rate': 0.0006055746058487232, 'batch_size': 16, 'epochs': 10, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 0.5, 'lstm_dropout': 0.0}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41346, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10330, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.21598393 -0.15172333  0.17908378 -0.2237712   0.19315846]...
# [I 2025-09-18 15:26:49,758] Trial 10 finished with value: 35.93105124753909 and parameters: {'hidden_size': 128, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0019440772177925266, 'batch_size': 64, 'epochs': 50, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.2}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [1.5051744 1.7448359 1.5923293 1.790598  0.       ]...
# [I 2025-09-18 15:41:46,947] Trial 11 finished with value: 35.8783875654021 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'relu', 'learning_rate': 0.00030499672474976544, 'batch_size': 32, 'epochs': 50, 'timesteps': 60, 'weight_decay': 1e-05, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 1 with value: 27.23398130312492.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.17224017  0.17716041 -0.14898747 -0.0997806  -0.1454012 ]...
# [I 2025-09-18 15:53:11,478] Trial 12 finished with value: 27.051927154596605 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0013388605435723652, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 12 with value: 27.051927154596605.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.17652881 -0.15830271 -0.1722349   0.15346184 -0.16576132]...
# [I 2025-09-18 16:04:40,314] Trial 13 finished with value: 26.691875047136232 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0013623072394225064, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 13 with value: 26.691875047136232.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.31248516  0.04051904 -0.02090133  0.13180561  0.3327318 ]...
# [I 2025-09-18 16:16:05,030] Trial 14 finished with value: 30.41008669996627 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.009759633392606621, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 13 with value: 26.691875047136232.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 10859865336 bytes.
# [I 2025-09-18 16:20:56,612] Trial 15 finished with value: inf and parameters: {'hidden_size': 128, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.001920734404105596, 'batch_size': 64, 'epochs': 10, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.1}. Best is trial 13 with value: 26.691875047136232.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.3309918   0.30291703  0.35958546 -0.2902027  -0.29625985]...
# [I 2025-09-18 16:32:17,337] Trial 16 finished with value: 27.41765151550815 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.000580941016007389, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 13 with value: 26.691875047136232.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.05135321  0.05910503  0.07348996 -0.03745793 -0.07331029]...
# [I 2025-09-18 16:55:45,640] Trial 17 finished with value: 37.30039897003591 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'gelu', 'learning_rate': 0.0036637761753591925, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 13 with value: 26.691875047136232.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.15435584 -0.2607495   0.23265776 -0.21783169 -0.20213392]...
# [I 2025-09-18 17:09:54,589] Trial 18 finished with value: 26.651563723967598 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.001421977390625334, 'batch_size': 64, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41346, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10330, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.507278    0.58334696  0.55219436 -0.46477404 -0.5380761 ]...
# [I 2025-09-18 17:18:42,862] Trial 19 finished with value: 31.666124608869247 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'activation': 'tanh', 'learning_rate': 0.0007588824513531168, 'batch_size': 64, 'epochs': 30, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [2.321815  2.3127608 3.3442776 2.4423602 1.9862998]...
# [I 2025-09-18 17:32:47,581] Trial 20 finished with value: 30.15479978229744 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'gelu', 'learning_rate': 0.0003453620893088562, 'batch_size': 64, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.30817074 -0.29446286 -0.23482636 -0.24449164 -0.21527791]...
# [I 2025-09-18 17:39:43,491] Trial 21 finished with value: 29.591700878546547 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.001391969564675495, 'batch_size': 64, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [ 0.19296515  0.01444357 -0.07522096 -0.00513951 -0.05960394]...
# [I 2025-09-18 17:46:38,733] Trial 22 finished with value: 30.315344922187485 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.003328012093228343, 'batch_size': 64, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.53752697  0.39718273  0.4930867  -0.51841766 -0.45770556]...
# [I 2025-09-18 17:49:01,470] Trial 23 finished with value: 31.779200857251126 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0014140193841723258, 'batch_size': 64, 'epochs': 10, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.0}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.2334328  -0.24031736  0.19663242  0.23222949  0.19536899]...
# [I 2025-09-18 18:12:26,411] Trial 24 finished with value: 29.688751766180744 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0008693137399909688, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.11689785  0.15560214  0.1537543   0.1582086  -0.14437023]...
# [I 2025-09-18 18:19:23,727] Trial 25 finished with value: 28.133563524263955 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0027982997018944204, 'batch_size': 64, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.1196252   0.05538553  0.11970621  0.08289618  0.12407805]...
# [I 2025-09-18 18:30:51,843] Trial 26 finished with value: 28.081990246826248 and parameters: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.0016165618172430207, 'batch_size': 64, 'epochs': 50, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41346, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10330, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.50894207  0.6805438   0.53252006 -0.59816295 -0.5386674 ]...
# [I 2025-09-18 18:33:50,017] Trial 27 finished with value: 31.156743090281854 and parameters: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0008045413957662289, 'batch_size': 64, 'epochs': 10, 'timesteps': 10, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.0}. Best is trial 18 with value: 26.651563723967598.
# Optuna trial error: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 15611518200 bytes.
# [I 2025-09-18 19:19:16,512] Trial 28 finished with value: inf and parameters: {'hidden_size': 256, 'num_layers': 1, 'dropout': 0.2, 'activation': 'gelu', 'learning_rate': 0.0004375961116673963, 'batch_size': 64, 'epochs': 50, 'timesteps': 40, 'weight_decay': 0.0001, 'grad_clip': 2.0, 'lstm_dropout': 0.2}. Best is trial 18 with value: 26.651563723967598.
#   LSTM Debug - Train features shape: (41296, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Val features shape: (10280, 32), type: <class 'numpy.ndarray'>
#   LSTM Debug - Feature sample: [-0.37080213  0.38897812 -0.3498682   0.34524885  0.2969881 ]...
# [I 2025-09-18 19:36:32,787] Trial 29 finished with value: 37.46090885046512 and parameters: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'activation': 'tanh', 'learning_rate': 0.0022799862255947303, 'batch_size': 32, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0, 'grad_clip': 2.0, 'lstm_dropout': 0.1}. Best is trial 18 with value: 26.651563723967598.
# Best parameters for 7_24: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.4, 'activation': 'tanh', 'learning_rate': 0.001421977390625334, 'batch_size': 64, 'epochs': 30, 'timesteps': 60, 'weight_decay': 0.0001, 'grad_clip': 1.0, 'lstm_dropout': 0.1}
# Best validation RMSE: 5.1625
#  7_24 tuning complete
#
# ================================================================================
# LSTM COMPONENT PREPARATION COMPLETE
# ================================================================================
# Best parameters saved for each day
# LSTMTemporalFeatureGenerator class ready
# TemporalDataLoader class ready
#
# Next Steps:
# 1. Integration team: Use LSTMTemporalFeatureGenerator in full pipeline
# 2. Full pipeline CV: Wrap entire models in 5-fold cross-validation
# 3. Models to evaluate: CapsNet-LSTM-LightGBM, CNN-LSTM-LightGBM, CapsNet-LSTM
# 4. Statistical analysis: Compare 5-fold results across models
# ================================================================================
#
# ================================================================================
# CORRECT 5-FOLD CV INTEGRATION:
# ================================================================================
#
# # PHASE 1: Hyperparameter Tuning (run once per day)
# from lstm_temporal_feature_generator import hyperparameter_tuning_lstm
# best_params = hyperparameter_tuning_lstm('7_24', max_combinations=10)
#
# # PHASE 2: 5-Fold Cross-Validation (main pipeline)
# from lstm_temporal_feature_generator import LSTMTemporalFeatureGenerator, TemporalDataLoader
# from sklearn.model_selection import TimeSeriesSplit
#
# # Initialize components
# data_loader = TemporalDataLoader()
# lstm_generator = LSTMTemporalFeatureGenerator(best_params)
#
# # Load data and split into learning (80%) and hold-out (20%)
# temporal_data, targets, _ = data_loader.load_temporal_data('7_24')
# n_total = len(temporal_data)
# n_learning = int(n_total * 0.8)
#
# learning_temporal = temporal_data[:n_learning]  # 80% learning set
# learning_targets = targets[:n_learning]
# holdout_temporal = temporal_data[n_learning:]   # 20% hold-out (untouched)
# holdout_targets = targets[n_learning:]
#
# # 5-Fold TimeSeriesSplit on 80% learning set
# tscv = TimeSeriesSplit(n_splits=5)
# fold_scores = []
#
# for fold, (train_idx, val_idx) in enumerate(tscv.split(learning_temporal)):
#     print(f"Fold {fold + 1}/5")
#
#     # Split data for this fold (expanding window)
#     train_temporal = learning_temporal[train_idx]  # Growing train set
#     val_temporal = learning_temporal[val_idx]      # Fixed-size val set
#     train_targets = learning_targets[train_idx]
#     val_targets = learning_targets[val_idx]
#
#     # Extract temporal features for this fold
#     train_temp_features, val_temp_features, _, _ = lstm_generator.train_and_extract_features(
#         train_temporal, train_targets, val_temporal, val_targets
#     )
#
#     # Extract spatial features (CapsNet/CNN)
#     train_spatial_features, val_spatial_features = capsnet_generator.train_and_extract_features(
#         train_images, train_targets, val_images, val_targets
#     )
#
#     # Combine features
#     train_combined = np.concatenate([train_temp_features, train_spatial_features], axis=1)
#     val_combined = np.concatenate([val_temp_features, val_spatial_features], axis=1)
#
#     # Train LightGBM meta-learner
#     lightgbm_model = LGBMRegressor(best_lightgbm_params)
#     lightgbm_model.fit(train_combined, train_targets)
#
#     # Validate on this fold
#     val_predictions = lightgbm_model.predict(val_combined)
#     fold_rmse = np.sqrt(mean_squared_error(val_targets, val_predictions))
#     fold_scores.append(fold_rmse)
#
#     print(f"  Fold {fold + 1} RMSE: {fold_rmse:.4f}")
#
# # Calculate cross-validation performance
# cv_mean = np.mean(fold_scores)
# cv_std = np.std(fold_scores)
# print(f"5-Fold CV Results: {cv_mean:.4f} ± {cv_std:.4f}")
#
# ================================================================================
